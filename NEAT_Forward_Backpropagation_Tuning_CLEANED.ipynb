# 12  -0.303658                  0.059638
# 13  -0.835370                 -0.251010
# 14   0.209893                  0.755203
# 15   0.833199                  0.961019
# 16   1.129996                  0.747481
# 17  -0.588967                  0.442065
# 18   0.491248                  0.774932
# 19   0.376310                 -0.182006
# 20   0.683287                 -0.161421
# 21  -0.246362                  0.654573
# 22   0.314980                 -0.442667
# 23   2.080483                  0.021249
# 24   0.664302                 -0.619985
# 25  -0.145166                  0.342153
# 26  -0.383398                  0.772364
# 27   0.116155                 -0.528938
# 28  -1.007669                  0.410924
# 29  -0.062840                  1.126440
# 30   0.319416                 -0.509653
# 31   0.263591                  0.589998
# 32   0.202228                  0.330924
# 33  -0.328085                 -1.157514
# 34   0.449154                 -0.688626
# 35   0.239724                 -0.070951
# 36  -0.324991                  0.167280
# 37   2.336160                 -0.672684
# 38   0.689636                 -0.829957
# 39   1.425281                 -0.424487

# %%
#On spécifie l'étude 1 ou l'étude 2
etude=2 #1 ou 2
ctrl_data = None

#Pour l'étude #1, on exclu le groupe 'IC' et 'SLI'
if etude == 1:
  #on exclu le groupe 'IC' et 'SLI'
  ctrl_data = df.loc[(df.Group != 'IC') & (df.Group != 'SLI')]
  print(f"Les groupes d'individus pour l'étude no. {etude} sont: {ctrl_data.Group.unique()}")
  print(f"Le nombre d'individus pour chaque type est: \n{ctrl_data.Group.value_counts()}")
else:
  #Pour l'etude #2, on inclu tous les individus
  ctrl_data = df.copy()
  print(f"Les groupes d'individus pour l'étude no. {etude} sont: {ctrl_data.Group.unique()}")
  print(f"Le nombre d'individus pour chaque type est: \n{ctrl_data.Group.value_counts()}")

#On renomme le group 'TD' à 'CTRL'
ctrl_data.loc[ctrl_data.Group == "TD", "Group"] = "CTRL"

#Pour l'étude no. 2, on doit renommer aussi le group 'IC' et 'SLI' à 'CTRL'
if etude == 2:
  #Pour l'étude #2, on renomme le group 'IC' et 'SLI'.  on a déjà renommer le groupe 'TD' ci-haut.
  ctrl_data.loc[ctrl_data.Group == "IC", "Group"] = "CTRL"
  ctrl_data.loc[ctrl_data.Group == "SLI", "Group"] = "CTRL"

y =ctrl_data["Group"]
print(f"\nLes individus du groupe pour l'étude no. {etude} sont: ", y.unique())
print(f"Le nombre d'individus pour chaque type sont: \n{ctrl_data.Group.value_counts()}")

#Pour les characteristiques, on inclus les 4 characteristiques suivante:
#print("\ctrl_data est:\n",ctrl_data)
X = ctrl_data.loc[:,['avg_f0', 'jitter_s', 'shimmer', 'mean_hnr']]

print("\nLes valeures 'y' sont:\n", y.value_counts())

print(f"\nLes valeurs de X sont:\n{X.count()}")
X
# Out:
# Les groupes d'individus pour l'étude no. 2 sont: ['ASD' 'SLI' 'IC' 'TD']
# Le nombre d'individus pour chaque type est:
# Group
# ASD    38
# IC     25
# TD     24
# SLI    21
# Name: count, dtype: int64
#
# Les individus du groupe pour l'étude no. 2 sont:  ['ASD' 'CTRL']
# Le nombre d'individus pour chaque type sont:
# Group
# CTRL    70
# ASD     38
# Name: count, dtype: int64
#
# Les valeures 'y' sont:
#  Group
# CTRL    70
# ASD     38
# Name: count, dtype: int64
#
# Les valeurs de X sont:
# avg_f0      108
# jitter_s    108
# shimmer     108
# mean_hnr    108
# dtype: int64
#      avg_f0  jitter_s   shimmer  mean_hnr
# 0    304.75  1.205160  1.377360     10.75
# 1    294.45  0.560049  1.389308     12.25
# 2    255.85  0.722608  1.185426     12.90
# 3    292.75  0.045519  1.645441      8.65
# 4    305.75  1.151768  1.544171      8.30
# ..      ...       ...       ...       ...
# 103  255.05  0.273689  1.302515      9.75
# 104  265.00  2.363517  1.299065      9.80
# 105  266.45  0.951328  1.517415     10.95
# 106  274.95  0.655506  1.264749      9.35
# 107  149.75  0.610251  1.570721      7.25
#
# [108 rows x 4 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

pca = PCA(n_components=4)
X_pca = pca.fit_transform(X)
print("Explained variance ratio:",(sum(pca.explained_variance_ratio_)))

X_Scaled = StandardScaler().fit_transform(X_pca)

#Convertir les classes en valeures binaires.
y_numeric = y.map({'ASD':1, 'CTRL':0})
print("\nLe nombre de d'individus(es) pour chaque catégorie:\n\n",y_numeric.value_counts())

print("\nIndividus(es) autistique:", np.count_nonzero(y_numeric == 1))
print("Individus(es) non autistique:", np.count_nonzero(y_numeric == 0))

print("\nX:",len(X_Scaled), "\ny_numeric:", len(y_numeric), "\n\n")
X=X_Scaled
y=y_numeric
print("y:\n", y)
print("X:\n", X)
# Out:
# Explained variance ratio: 0.9999999999999999
#
# Le nombre de d'individus(es) pour chaque catégorie:
#
#  Group
# 0    70
# 1    38
# Name: count, dtype: int64
#
# Individus(es) autistique: 38
# Individus(es) non autistique: 70
#
# X: 108
# y_numeric: 108
#
#
# y:
#  0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 103    0
# 104    0
# 105    0
# 106    0
# 107    0
# Name: Group, Length: 108, dtype: int64
# X:
#  [[ 6.25593191e-01 -5.54180146e-02  2.02375624e-01  5.28334879e-01]
#  [ 3.55804368e-01  7.90893840e-01 -4.68271985e-01  7.74774606e-01]
#  [-6.58972889e-01  1.58759157e+00 -1.54544289e-01 -1.11055634e-01]
#  [ 3.08465546e-01 -8.35992528e-01 -1.44637390e+00  1.11096316e+00]
#  [ 6.50098478e-01 -1.20017008e+00 -9.27116546e-02  8.38494458e-01]
#  [-1.69060647e-01  9.59885799e-01 -5.81627097e-01  5.37856828e-01]
#  [ 5.78489918e-01 -7.00809414e-01 -9.84052910e-01  8.74225629e-01]
#  [ 1.39800315e+00 -1.33023434e-01 -1.63419288e+00  4.24070024e-01]
#  [ 1.33995356e+00 -1.06333803e+00 -5.21255440e-01  6.74334853e-01]
#  [ 1.17760860e+00 -1.35559129e+00 -6.36952601e-01  1.59415432e+00]
#  [-1.01470647e+00  1.34735649e+00 -4.44501346e-01  1.12387811e+00]
#  [-1.15799454e+00 -1.03437574e+00 -9.63637568e-01  1.47725344e+00]
#  [ 7.69423118e-01 -6.31100496e-01 -1.99482846e+00  1.27921597e+00]
#  [ 1.42829984e+00 -9.52920153e-01 -1.11131811e+00  8.24940187e-01]
#  [ 8.88790494e-01 -6.00112708e-02 -1.08307374e+00  6.95534710e-01]
#  [ 3.00826355e-01  9.79149620e-01 -2.71191518e-01 -2.42370247e-01]
#  [ 2.11128313e-01 -8.21981358e-01  1.03426040e+00 -5.40821048e-01]
#  [ 4.73872853e-02 -1.16732671e+00  1.28600560e+00 -2.12625085e-01]
#  [-1.61525497e+00 -1.39380650e+00 -4.86454156e-01 -1.10693906e+00]
#  [-6.74777107e-01 -9.09699426e-01 -3.53020027e-01 -2.83670828e-01]
#  [ 1.09420079e-01  5.98840065e-01  1.86963578e+00  3.19224632e-01]
#  [ 1.01262760e+00 -1.65151196e+00  2.60012061e-03 -1.64861229e+00]
#  [-2.90305719e-01 -8.10210381e-01  2.84327444e-01 -1.05338942e+00]
#  [-1.19611240e+00 -1.68033521e-01 -1.13494177e+00 -3.94269907e-01]
#  [ 8.83754795e-01 -1.59548322e+00  1.29501128e+00 -2.25244158e+00]
#  [-2.49118562e-01 -1.40125883e+00  7.12491596e-01 -4.58847573e-01]
#  [ 6.42442959e-02 -4.78811926e-01 -4.82444307e-01 -5.54045811e-01]
#  [ 9.17070399e-01 -1.35029528e+00  2.63394281e+00 -2.63256742e-01]
#  [-6.21876000e-01 -7.60143054e-01  1.10595910e+00 -1.24770034e+00]
#  [-2.07228471e+00 -8.04928233e-01  2.37933274e+00  4.36912474e-01]
#  [-1.72791184e+00 -2.32901847e-01 -2.17927124e-01 -4.66722636e-02]
#  [-1.11936146e+00 -1.58871610e+00  8.99354394e-01  1.48133192e+00]
#  [-6.82310012e-01  1.57162112e-01 -9.99169186e-01 -4.88028791e-01]
#  [-4.20638782e-01 -1.75912187e-02  1.61457227e+00  4.25565906e-01]
#  [-3.81615518e-01  5.37127231e-01 -7.74258751e-02  1.47316495e+00]
#  [-1.59208086e-01 -2.96294895e-01 -5.69577734e-01 -7.31192867e-01]
#  [-3.45374366e+00  3.46841241e-01 -7.24579993e-01  9.72542131e-01]]

# %%
import torch
import torch.nn as nn

# Define PyTorch wrapper for evolved NEAT networks
class EvolvedNN(nn.Module):
    def __init__(self, neat_net, genome):
        super().__init__()
        self.layers = nn.ModuleList()
        self.node_map = {}
        layer_index = 0
        neuron_index = 0

        # Map input nodes
        for node_id in neat_net.input_nodes:
            self.node_map[node_id] = (layer_index, neuron_index)
            neuron_index += 1

        # Add hidden layer if any
        hidden_nodes = [n for n in genome.nodes if n not in neat_net.input_nodes and n not in neat_net.output_nodes]
        num_hidden = len(hidden_nodes)

        if num_hidden > 0:
            layer_index += 1
            neuron_index = 0
            self.layers.append(nn.Linear(len(neat_net.input_nodes), num_hidden))
            for node_id in hidden_nodes:
                self.node_map[node_id] = (layer_index, neuron_index)
                neuron_index += 1

        # Output layer
        layer_index += 1
        neuron_index = 0
        input_size = num_hidden if num_hidden > 0 else len(neat_net.input_nodes)
        self.layers.append(nn.Linear(input_size, len(neat_net.output_nodes)))
        for node_id in neat_net.output_nodes:
            self.node_map[node_id] = (layer_index, neuron_index)
            neuron_index += 1

        self.load_neat_weights(genome)

    def forward(self, x):
        for i, layer in enumerate(self.layers):
            x = layer(x)
            if i < len(self.layers) - 1 and i > 0:
                x = torch.relu(x)
        return x

    def load_neat_weights(self, genome):
        for conn in genome.connections.values():
            if conn.enabled:
                in_node, out_node = conn.key
                weight = conn.weight
                in_layer, in_neuron = self.node_map.get(in_node, (None, None))
                out_layer, out_neuron = self.node_map.get(out_node, (None, None))
                if in_layer is not None and out_layer is not None and out_layer < len(self.layers):
                    try:
                        self.layers[out_layer].weight.data[out_neuron, in_neuron] = weight
                        self.layers[out_layer].bias.data[out_neuron] = genome.nodes[out_node].bias
                    except IndexError:
                        pass

# %%
#Version NEAT avec généralisation et optimisation.

import neat
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Splittimg data into training and testing.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Define fitness function
def eval_genome(genome, config):
    net = neat.nn.FeedForwardNetwork.create(genome, config)
    correct = 0
    for xi, target in zip(X_train, y_train):
        output = net.activate(xi)
        if np.argmax(output) == target:
            correct += 1
    return correct / len(y_train)  # Accuracy as fitness

best_fitness_log = []

def eval_genomes(genomes, config):
    global best_fitness_log
    for genome_id, genome in genomes:
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        fitness = eval_genome(genome, config)
        genome.fitness = fitness
    best_fitness_log.append(max([g.fitness for _, g in genomes]))

# Configure NEAT
config_path = "./neat_cfg_vis.txt"
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation, config_path)

# Run NEAT
pop = neat.Population(config)
stats = neat.StatisticsReporter()
pop.add_reporter(stats)
pop.add_reporter(neat.StdOutReporter(True))

winner = pop.run(eval_genomes, 100)

# Get the best model (winner)
net = neat.nn.FeedForwardNetwork.create(winner, config)

# Predict on test data
y_pred = []
for x in X_test:
    output = net.activate(x)
    predicted_class = np.argmax(output)  # Get class with highest probability
    y_pred.append(predicted_class)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("NEAT Confusion Matrix")
plt.show()
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.68000 stdev: 0.00000
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.047, standard deviation 0.428
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   100      0.7    0.000     0
# Total extinctions: 0
# Generation time: 0.050 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.66560 stdev: 0.07055
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.346
# Mean genetic distance 1.025, standard deviation 0.432
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   100      0.7    0.346     1
# Total extinctions: 0
# Generation time: 0.085 sec (0.068 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 0.67280 stdev: 0.05040
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.353
# Mean genetic distance 0.992, standard deviation 0.431
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   100      0.7    0.353     2
# Total extinctions: 0
# Generation time: 0.098 sec (0.078 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 0.67280 stdev: 0.05040
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.353
# Mean genetic distance 0.996, standard deviation 0.476
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   100      0.7    0.353     3
# Total extinctions: 0
# Generation time: 0.043 sec (0.069 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 0.68000 stdev: 0.00000
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 0.961, standard deviation 0.432
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   100      0.7    0.000     4
# Total extinctions: 0
# Generation time: 0.046 sec (0.065 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 0.66560 stdev: 0.07055
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.346
# Mean genetic distance 1.024, standard deviation 0.473
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   100      0.7    0.346     5
# Total extinctions: 0
# Generation time: 0.041 sec (0.061 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 0.67640 stdev: 0.03582
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.356
# Mean genetic distance 1.192, standard deviation 0.563
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   100      0.7    0.356     6
# Total extinctions: 0
# Generation time: 0.041 sec (0.058 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 0.65227 stdev: 0.09458
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.332
# Mean genetic distance 1.129, standard deviation 0.446
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   100      0.7    0.332     7
# Total extinctions: 0
# Generation time: 0.062 sec (0.058 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 0.65747 stdev: 0.08576
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.337
# Mean genetic distance 1.462, standard deviation 0.606
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   100      0.7    0.337     8
# Total extinctions: 0
# Generation time: 0.059 sec (0.058 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 0.65840 stdev: 0.08550
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
# Average adjusted fitness: 0.338
# Mean genetic distance 2.107, standard deviation 1.047
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    94      0.7    0.338     9
#      2    0     6       --       --     0
# Total extinctions: 0
# Generation time: 0.047 sec (0.057 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 0.67640 stdev: 0.03582
# Best fitness: 0.68000 - size: (2, 0) - species 1 - id 1
#
# Species 1 with 94 members is stagnated: removing it
# Average adjusted fitness: 0.000
# Mean genetic distance 1.082, standard deviation 0.489
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2    1   100      0.7    0.000     0
# Total extinctions: 0
# Generation time: 0.055 sec (0.058 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 0.66813 stdev: 0.06502
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
# Average adjusted fitness: 0.428
# Mean genetic distance 2.131, standard deviation 0.972
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2    2    91      0.7    0.428     1
#      3    0     9       --       --     0
# Total extinctions: 0
# Generation time: 0.055 sec (0.055 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 0.66240 stdev: 0.07926
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
# Average adjusted fitness: 0.434
# Mean genetic distance 2.459, standard deviation 0.986
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2    3    58      0.7    0.469     2
#      3    1    36      0.7    0.400     0
#      4    0     6       --       --     0
# Total extinctions: 0
# Generation time: 0.065 sec (0.051 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 0.67360 stdev: 0.04516
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
# Average adjusted fitness: 0.354
# Mean genetic distance 2.428, standard deviation 0.868
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2    4    47      0.7    0.360     3
#      3    2    32      0.7    0.342     1
#      4    1    21      0.7    0.360     0
# Total extinctions: 0
# Generation time: 0.062 sec (0.053 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 0.67280 stdev: 0.05040
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
# Average adjusted fitness: 0.352
# Mean genetic distance 2.468, standard deviation 0.815
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2    5    41      0.7    0.352     4
#      3    3    36      0.7    0.360     2
#      4    2    23      0.7    0.343     1
# Total extinctions: 0
# Generation time: 0.047 sec (0.053 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: 0.67640 stdev: 0.03582
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
# Average adjusted fitness: 0.357
# Mean genetic distance 2.480, standard deviation 0.800
# Population of 99 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2    6    25      0.7    0.360     5
#      3    4    26      0.7    0.350     3
#      4    3    32      0.7    0.360     2
#      5    0    16       --       --     0
# Total extinctions: 0
# Generation time: 0.065 sec (0.056 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 0.66545 stdev: 0.07089
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
# Average adjusted fitness: 0.345
# Mean genetic distance 2.452, standard deviation 0.809
# Population of 100 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2    7    18      0.7    0.346     6
#      3    5    30      0.7    0.346     4
#      4    4    21      0.7    0.349     3
#      5    1    31      0.7    0.337     0
# Total extinctions: 0
# Generation time: 0.060 sec (0.058 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 0.66560 stdev: 0.07055
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
# Average adjusted fitness: 0.346
# Mean genetic distance 2.571, standard deviation 0.807
# Population of 100 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2    8    23      0.7    0.340     7
#      3    6    25      0.7    0.348     5
#      4    5    26      0.7    0.360     4
#      5    2    20      0.7    0.337     1
#      6    0     6       --       --     0
# Total extinctions: 0
# Generation time: 0.054 sec (0.057 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 0.66867 stdev: 0.06459
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
# Average adjusted fitness: 0.385
# Mean genetic distance 2.457, standard deviation 0.861
# Population of 99 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2    9    20      0.7    0.413     8
#      3    7    10      0.7    0.413     6
#      4    6    16      0.7    0.399     5
#      5    3    12      0.7    0.413     2
#      6    1    41      0.7    0.284     0
# Total extinctions: 0
# Generation time: 0.073 sec (0.058 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 0.67636 stdev: 0.03600
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
# Average adjusted fitness: 0.355
# Mean genetic distance 2.442, standard deviation 0.969
# Population of 100 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   10    16      0.7    0.360     9
#      3    8    16      0.7    0.360     7
#      4    7    19      0.7    0.337     6
#      5    4    10      0.7    0.360     3
#      6    2    39      0.7    0.360     1
# Total extinctions: 0
# Generation time: 0.106 sec (0.064 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: 0.67280 stdev: 0.05040
# Best fitness: 0.68000 - size: (2, 1) - species 2 - id 1052
#
# Species 2 with 16 members is stagnated: removing it
# Average adjusted fitness: 0.353
# Mean genetic distance 2.312, standard deviation 0.961
# Population of 100 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      5   36    47      0.9    0.414     9
#      7   15    53      0.9    0.524    10
# Total extinctions: 0
# Generation time: 0.068 sec (0.081 average)
#
#  ****** Running generation 52 ******
#
# Population's average fitness: 0.78493 stdev: 0.13701
# Best fitness: 0.93333 - size: (2, 3) - species 7 - id 4668
#
# Species 5 with 47 members is stagnated: removing it
# Average adjusted fitness: 0.258
# Mean genetic distance 1.059, standard deviation 0.421
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   16   100      0.9    0.258    11
# Total extinctions: 0
# Generation time: 0.075 sec (0.080 average)
#
#  ****** Running generation 53 ******
#
# Population's average fitness: 0.82987 stdev: 0.10748
# Best fitness: 0.93333 - size: (2, 3) - species 7 - id 4668
# Average adjusted fitness: 0.483
# Mean genetic distance 1.505, standard deviation 0.676
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   17    95      0.9    0.483    12
#      8    0     5       --       --     0
# Total extinctions: 0
# Generation time: 0.075 sec (0.078 average)
#
#  ****** Running generation 54 ******
#
# Population's average fitness: 0.83227 stdev: 0.09844
# Best fitness: 0.93333 - size: (2, 3) - species 7 - id 4668
# Average adjusted fitness: 0.499
# Mean genetic distance 1.828, standard deviation 0.650
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   18    65      0.9    0.573    13
#      8    1    35      0.9    0.424     0
# Total extinctions: 0
# Generation time: 0.077 sec (0.078 average)
#
#  ****** Running generation 55 ******
#
# Population's average fitness: 0.82267 stdev: 0.12105
# Best fitness: 0.93333 - size: (2, 3) - species 8 - id 4668
# Average adjusted fitness: 0.648
# Mean genetic distance 1.933, standard deviation 0.735
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   19    56      0.9    0.697    14
#      8    2    33      0.9    0.599     0
#      9    0    11       --       --     0
# Total extinctions: 0
# Generation time: 0.085 sec (0.079 average)
#
#  ****** Running generation 56 ******
#
# Population's average fitness: 0.81520 stdev: 0.11026
# Best fitness: 0.93333 - size: (2, 3) - species 8 - id 4668
# Average adjusted fitness: 0.371
# Mean genetic distance 1.998, standard deviation 0.776
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   20    59      0.9    0.419    15
#      8    3    12      0.9    0.352     1
#      9    1    29      0.9    0.343     0
# Total extinctions: 0
# Generation time: 0.094 sec (0.079 average)
#
#  ****** Running generation 57 ******
#
# Population's average fitness: 0.80267 stdev: 0.12125
# Best fitness: 0.93333 - size: (2, 3) - species 7 - id 4668
# Average adjusted fitness: 0.349
# Mean genetic distance 1.982, standard deviation 0.689
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   21    41      0.9    0.445    16
#      8    4    25      0.9    0.203     2
#      9    2    34      0.9    0.399     0
# Total extinctions: 0
# Generation time: 0.073 sec (0.079 average)
#
#  ****** Running generation 58 ******
#
# Population's average fitness: 0.79253 stdev: 0.12771
# Best fitness: 0.93333 - size: (2, 3) - species 8 - id 4668
# Average adjusted fitness: 0.608
# Mean genetic distance 1.922, standard deviation 0.725
# Population of 99 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   22    43      0.9    0.672    17
#      8    5    15      0.9    0.536     3
#      9    3    41      0.9    0.616     1
# Total extinctions: 0
# Generation time: 0.099 sec (0.082 average)
#
#  ****** Running generation 59 ******
#
# Population's average fitness: 0.81751 stdev: 0.11126
# Best fitness: 0.93333 - size: (2, 3) - species 7 - id 4668
# Average adjusted fitness: 0.481
# Mean genetic distance 1.912, standard deviation 0.781
# Population of 99 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   23    41      0.9    0.516    18
#      8    6    18      0.9    0.420     4
#      9    4    40      0.9    0.506     2
# Total extinctions: 0
# Generation time: 0.071 sec (0.080 average)
#
#  ****** Running generation 60 ******
#
# Population's average fitness: 0.82155 stdev: 0.09950
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.417
# Mean genetic distance 1.855, standard deviation 0.735
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      7   24    14      0.9    0.438    19
#      8    7    50      0.9    0.395     5
#      9    5    36      0.9    0.417     0
# Total extinctions: 0
# Generation time: 0.069 sec (0.079 average)
#
#  ****** Running generation 61 ******
#
# Population's average fitness: 0.79267 stdev: 0.14264
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
#
# Species 7 with 14 members is stagnated: removing it
# Average adjusted fitness: 0.625
# Mean genetic distance 1.638, standard deviation 0.736
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      8    8    55      0.9    0.606     6
#      9    6    45      0.9    0.644     1
# Total extinctions: 0
# Generation time: 0.088 sec (0.081 average)
#
#  ****** Running generation 62 ******
#
# Population's average fitness: 0.79600 stdev: 0.12076
# Best fitness: 0.93333 - size: (2, 3) - species 8 - id 4668
# Average adjusted fitness: 0.638
# Mean genetic distance 1.603, standard deviation 0.694
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      8    9    56      0.9    0.614     7
#      9    7    44      0.9    0.663     2
# Total extinctions: 0
# Generation time: 0.080 sec (0.081 average)
#
#  ****** Running generation 63 ******
#
# Population's average fitness: 0.79267 stdev: 0.13969
# Best fitness: 0.93333 - size: (2, 3) - species 8 - id 4668
# Average adjusted fitness: 0.556
# Mean genetic distance 1.638, standard deviation 0.686
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      8   10    53      0.9    0.528     8
#      9    8    47      0.9    0.584     3
# Total extinctions: 0
# Generation time: 0.070 sec (0.081 average)
#
#  ****** Running generation 64 ******
#
# Population's average fitness: 0.81067 stdev: 0.11872
# Best fitness: 0.93333 - size: (2, 3) - species 8 - id 4668
# Average adjusted fitness: 0.504
# Mean genetic distance 1.737, standard deviation 0.661
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      8   11    49      0.9    0.497     9
#      9    9    51      0.9    0.512     4
# Total extinctions: 0
# Generation time: 0.072 sec (0.080 average)
#
#  ****** Running generation 65 ******
#
# Population's average fitness: 0.81613 stdev: 0.12222
# Best fitness: 0.93333 - size: (2, 3) - species 8 - id 4668
#
# Species 8 with 49 members is stagnated: removing it
# Average adjusted fitness: 0.498
# Mean genetic distance 1.266, standard deviation 0.450
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   10   100      0.9    0.498     5
# Total extinctions: 0
# Generation time: 0.069 sec (0.078 average)
#
#  ****** Running generation 66 ******
#
# Population's average fitness: 0.80187 stdev: 0.10928
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.402
# Mean genetic distance 1.218, standard deviation 0.492
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   11   100      0.9    0.402     6
# Total extinctions: 0
# Generation time: 0.091 sec (0.078 average)
#
#  ****** Running generation 67 ******
#
# Population's average fitness: 0.81133 stdev: 0.12702
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.518
# Mean genetic distance 1.087, standard deviation 0.473
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   12   100      0.9    0.518     7
# Total extinctions: 0
# Generation time: 0.100 sec (0.081 average)
#
#  ****** Running generation 68 ******
#
# Population's average fitness: 0.81400 stdev: 0.12801
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.534
# Mean genetic distance 1.066, standard deviation 0.438
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   13   100      0.9    0.534     8
# Total extinctions: 0
# Generation time: 0.086 sec (0.080 average)
#
#  ****** Running generation 69 ******
#
# Population's average fitness: 0.81307 stdev: 0.12744
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.520
# Mean genetic distance 1.014, standard deviation 0.413
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   14   100      0.9    0.520     9
# Total extinctions: 0
# Generation time: 0.120 sec (0.084 average)
#
#  ****** Running generation 70 ******
#
# Population's average fitness: 0.83213 stdev: 0.10751
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.512
# Mean genetic distance 1.263, standard deviation 0.419
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   15   100      0.9    0.512    10
# Total extinctions: 0
# Generation time: 0.077 sec (0.085 average)
#
#  ****** Running generation 71 ******
#
# Population's average fitness: 0.82107 stdev: 0.10834
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.381
# Mean genetic distance 1.333, standard deviation 0.464
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   16   100      0.9    0.381    11
# Total extinctions: 0
# Generation time: 0.481 sec (0.124 average)
#
#  ****** Running generation 72 ******
#
# Population's average fitness: 0.80587 stdev: 0.14796
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.646
# Mean genetic distance 1.248, standard deviation 0.428
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   17   100      0.9    0.646    12
# Total extinctions: 0
# Generation time: 0.662 sec (0.183 average)
#
#  ****** Running generation 73 ******
#
# Population's average fitness: 0.83187 stdev: 0.10068
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.379
# Mean genetic distance 1.204, standard deviation 0.425
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   18   100      0.9    0.379    13
# Total extinctions: 0
# Generation time: 0.457 sec (0.221 average)
#
#  ****** Running generation 74 ******
#
# Population's average fitness: 0.84307 stdev: 0.09107
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.376
# Mean genetic distance 1.312, standard deviation 0.450
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   19   100      0.9    0.376    14
# Total extinctions: 0
# Generation time: 0.142 sec (0.228 average)
#
#  ****** Running generation 75 ******
#
# Population's average fitness: 0.84400 stdev: 0.09370
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.524
# Mean genetic distance 2.264, standard deviation 1.075
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   20    94      0.9    0.524    15
#     10    0     4       --       --     0
#     11    0     2       --       --     0
# Total extinctions: 0
# Generation time: 0.134 sec (0.235 average)
#
#  ****** Running generation 76 ******
#
# Population's average fitness: 0.83253 stdev: 0.12397
# Best fitness: 0.93333 - size: (2, 3) - species 9 - id 5758
# Average adjusted fitness: 0.391
# Mean genetic distance 2.570, standard deviation 0.927
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   21    70      0.9    0.637    16
#     10    1    26      0.9    0.503     0
#     11    1     4      0.3    0.033     0
# Total extinctions: 0
# Generation time: 0.143 sec (0.240 average)
#
#  ****** Running generation 77 ******
#
# Population's average fitness: 0.79707 stdev: 0.13982
# Best fitness: 0.94667 - size: (2, 4) - species 9 - id 7472
# Average adjusted fitness: 0.470
# Mean genetic distance 2.643, standard deviation 0.979
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   41    57      1.0    0.245    12
#     13    5    43      0.9    0.197     0
# Total extinctions: 0
# Generation time: 0.089 sec (0.098 average)
#
#  ****** Running generation 97 ******
#
# Population's average fitness: 0.85480 stdev: 0.10360
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.411
# Mean genetic distance 1.947, standard deviation 0.838
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   42    52      1.0    0.436    13
#     13    6    48      0.9    0.387     0
# Total extinctions: 0
# Generation time: 0.074 sec (0.090 average)
#
#  ****** Running generation 98 ******
#
# Population's average fitness: 0.82533 stdev: 0.12167
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.426
# Mean genetic distance 1.927, standard deviation 0.823
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   43    47      1.0    0.418    14
#     13    7    53      0.9    0.433     0
# Total extinctions: 0
# Generation time: 0.076 sec (0.090 average)
#
#  ****** Running generation 99 ******
#
# Population's average fitness: 0.84627 stdev: 0.10097
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.500
# Mean genetic distance 1.825, standard deviation 0.798
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   44    48      1.0    0.508    15
#     13    8    52      0.9    0.493     0
# Total extinctions: 0
# Generation time: 0.117 sec (0.095 average)

# %%
# Wrap winner into PyTorch-compatible model
model = EvolvedNN(net, winner)

# Debug: Show architecture
print("✅ Final model structure:")
for i, layer in enumerate(model.layers):
    print(layer)

print(f"🏁 Final winner: {len(winner.nodes)} nodes, {len(winner.connections)} connections")

# Save winner genome
with open("winner_genome.pkl", "wb") as f:
    pickle.dump(winner, f)

# Save PyTorch weights
torch.save(model.state_dict(), "evolved_neat_model.pt")
# Out:
# ✅ Final model structure:
# Linear(in_features=4, out_features=2, bias=True)
# 🏁 Final winner: 2 nodes, 4 connections

# %%
import json
with open("./neat_fitness_log.json", "w") as f:
    json.dump(best_fitness_log, f)

# %%
def draw_net(genome, config, filename="network.png"):
    """ Visualize a neural network genome structure. """
    net = neat.nn.FeedForwardNetwork.create(genome, config)

    G = nx.DiGraph()

    m_net = net

    # Add nodes and assign colors
    # input nodes are blue, output nodes are red, and hidden nodes are gray
    node_colors = {}
    for i in net.input_nodes:
        G.add_node(i)
        node_colors[i] = 'yellow'  # Input layer
    for i in net.output_nodes:
        G.add_node(i)
        node_colors[i] = 'green'  # Output layer
    for conn in genome.connections.values():
        if conn.enabled:
            G.add_edge(conn.key[0], conn.key[1], weight=conn.weight)
            if conn.key[0] not in node_colors:  # Check if node is hidden
                G.add_node(conn.key[0])
                node_colors[conn.key[0]] = 'gray'
            if conn.key[1] not in node_colors:  # Check if node is hidden
                G.add_node(conn.key[1])
                node_colors[conn.key[1]] = 'gray'

    # Draw graph using node_colors for node color mapping
    colors = [node_colors[n] for n in G.nodes]
    pos = nx.spring_layout(G)
    nx.draw(G, pos, node_color=colors, with_labels=True, edge_color='gray', alpha=0.8)
    plt.savefig(filename)
    plt.show()

draw_net(winner, config)

# %%
def plot_fitness(stats):
    gen = list(range(len(stats.most_fit_genomes)))
    fitness = [g.fitness for g in stats.most_fit_genomes]

    plt.plot(gen, fitness, marker='o', linestyle='-')
    plt.xlabel("Generations")
    plt.ylabel("Best Fitness")
    plt.title("Fitness Progress Over Generations")
    plt.grid()
    plt.show()

# Call after running NEAT
plot_fitness(stats)

# %%
# Evolve population and get winner
winner = pop.run(eval_genomes, 100)

# Confirm winner genome details
print(f"🏁 Final winner: {len(winner.nodes)} nodes, {len(winner.connections)} connections")

# Create NEAT network and PyTorch wrapper
net = neat.nn.FeedForwardNetwork.create(winner, config)
model = EvolvedNN(net, winner)

# Confirm model layers
print("✅ Final model structure:")
for i, layer in enumerate(model.layers):
    print(layer)

# Save winner genome
with open("winner_genome.pkl", "wb") as f:
    pickle.dump(winner, f)

# Save model weights
torch.save(model.state_dict(), "evolved_neat_model.pt")
# Out:
#  ****** Running generation 100 ******
#
# Population's average fitness: 0.84733 stdev: 0.11532
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.555
# Mean genetic distance 1.823, standard deviation 0.672
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   45    49      1.0    0.577    16
#     13    9    51      0.9    0.533     1
# Total extinctions: 0
# Generation time: 0.135 sec (0.095 average)
#
#  ****** Running generation 101 ******
#
# Population's average fitness: 0.84960 stdev: 0.10761
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.543
# Mean genetic distance 1.784, standard deviation 0.664
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   46    47      1.0    0.562    17
#     13   10    53      0.9    0.524     2
# Total extinctions: 0
# Generation time: 0.137 sec (0.096 average)
#
#  ****** Running generation 102 ******
#
# Population's average fitness: 0.85040 stdev: 0.11179
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.478
# Mean genetic distance 1.944, standard deviation 0.702
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   47    44      1.0    0.486    18
#     13   11    56      0.9    0.469     3
# Total extinctions: 0
# Generation time: 0.165 sec (0.104 average)
#
#  ****** Running generation 103 ******
#
# Population's average fitness: 0.82240 stdev: 0.12876
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.504
# Mean genetic distance 1.819, standard deviation 0.714
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   48    45      1.0    0.513    19
#     13   12    55      0.9    0.494     4
# Total extinctions: 0
# Generation time: 0.138 sec (0.108 average)
#
#  ****** Running generation 104 ******
#
# Population's average fitness: 0.84760 stdev: 0.10644
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.529
# Mean genetic distance 1.808, standard deviation 0.710
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   49    54      1.0    0.543    20
#     13   13    46      0.9    0.515     5
# Total extinctions: 0
# Generation time: 0.131 sec (0.114 average)
#
#  ****** Running generation 105 ******
#
# Population's average fitness: 0.86333 stdev: 0.07401
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.330
# Mean genetic distance 1.867, standard deviation 0.641
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   50    52      1.0    0.334    21
#     13   14    48      0.9    0.326     6
# Total extinctions: 0
# Generation time: 0.139 sec (0.120 average)
#
#  ****** Running generation 106 ******
#
# Population's average fitness: 0.84813 stdev: 0.10534
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.422
# Mean genetic distance 1.942, standard deviation 0.699
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   51    47      1.0    0.401    22
#     13   15    51      0.9    0.444     7
#     14    0     2       --       --     0
# Total extinctions: 0
# Generation time: 0.155 sec (0.127 average)
#
#  ****** Running generation 107 ******
#
# Population's average fitness: 0.86373 stdev: 0.08411
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.300
# Mean genetic distance 2.305, standard deviation 1.189
# Population of 99 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   52    42      1.0    0.351    23
#     13   16    45      0.9    0.342     8
#     14    1    12      0.8    0.207     0
# Total extinctions: 0
# Generation time: 0.139 sec (0.133 average)
#
#  ****** Running generation 108 ******
#
# Population's average fitness: 0.83946 stdev: 0.11989
# Best fitness: 0.96000 - size: (2, 4) - species 9 - id 8210
# Average adjusted fitness: 0.396
# Mean genetic distance 2.707, standard deviation 1.244
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      9   53    35      1.0    0.466    24
#     13   17    49      0.9    0.463     9
#     14    2    16      0.8    0.259     0
# Total extinctions: 0
# Generation time: 0.184 sec (0.144 average)
#
#  ****** Running generation 109 ******
#
# Population's average fitness: 0.81773 stdev: 0.14049
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
#
# Species 9 with 35 members is stagnated: removing it
# Average adjusted fitness: 0.573
# Mean genetic distance 2.552, standard deviation 1.032
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   18    73      1.0    0.635     0
#     14    3    27      0.9    0.512     0
# Total extinctions: 0
# Generation time: 0.137 sec (0.146 average)
#
#  ****** Running generation 110 ******
#
# Population's average fitness: 0.81093 stdev: 0.13461
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.519
# Mean genetic distance 2.805, standard deviation 1.016
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   19    75      1.0    0.545     1
#     14    4     2      0.9    0.493     0
#     15    0    23       --       --     0
# Total extinctions: 0
# Generation time: 0.172 sec (0.150 average)
#
#  ****** Running generation 111 ******
#
# Population's average fitness: 0.81973 stdev: 0.11925
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.399
# Mean genetic distance 2.669, standard deviation 1.051
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   20    64      1.0    0.597     2
#     14    5     5      0.4    0.093     1
#     15    1    31      0.9    0.507     0
# Total extinctions: 0
# Generation time: 0.161 sec (0.152 average)
#
#  ****** Running generation 112 ******
#
# Population's average fitness: 0.79587 stdev: 0.15583
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.409
# Mean genetic distance 2.573, standard deviation 0.981
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   21    57      1.0    0.585     3
#     14    6    10      0.5    0.117     2
#     15    2    33      0.9    0.524     0
# Total extinctions: 0
# Generation time: 0.133 sec (0.149 average)
#
#  ****** Running generation 113 ******
#
# Population's average fitness: 0.79627 stdev: 0.16573
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.544
# Mean genetic distance 2.426, standard deviation 0.952
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   22    57      1.0    0.709     4
#     14    7    11      0.7    0.256     3
#     15    3    32      0.9    0.665     0
# Total extinctions: 0
# Generation time: 0.171 sec (0.152 average)
#
#  ****** Running generation 114 ******
#
# Population's average fitness: 0.82347 stdev: 0.11451
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.432
# Mean genetic distance 2.484, standard deviation 0.923
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   23    54      1.0    0.544     5
#     14    8    15      0.7    0.291     4
#     15    4    31      0.9    0.462     1
# Total extinctions: 0
# Generation time: 0.134 sec (0.153 average)
#
#  ****** Running generation 115 ******
#
# Population's average fitness: 0.80280 stdev: 0.12921
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.424
# Mean genetic distance 2.334, standard deviation 0.823
# Population of 99 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   24    49      1.0    0.520     6
#     14    9    23      0.7    0.277     5
#     15    5    27      0.9    0.474     0
# Total extinctions: 0
# Generation time: 0.150 sec (0.154 average)
#
#  ****** Running generation 116 ******
#
# Population's average fitness: 0.82545 stdev: 0.09971
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.354
# Mean genetic distance 2.167, standard deviation 0.806
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   25    37      1.0    0.417     7
#     14   10    30      0.8    0.250     6
#     15    6    33      0.9    0.394     1
# Total extinctions: 0
# Generation time: 0.147 sec (0.153 average)
#
#  ****** Running generation 117 ******
#
# Population's average fitness: 0.82107 stdev: 0.10160
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.416
# Mean genetic distance 1.844, standard deviation 0.674
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   26    34      1.0    0.483     8
#     14   11    36      0.8    0.320     7
#     15    7    30      0.9    0.444     0
# Total extinctions: 0
# Generation time: 0.137 sec (0.153 average)
#
#  ****** Running generation 118 ******
#
# Population's average fitness: 0.82827 stdev: 0.10294
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.538
# Mean genetic distance 1.955, standard deviation 0.677
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   27    42      1.0    0.585     9
#     14   12    32      0.9    0.455     0
#     15    8    26      0.9    0.574     1
# Total extinctions: 0
# Generation time: 0.170 sec (0.151 average)
#
#  ****** Running generation 119 ******
#
# Population's average fitness: 0.82827 stdev: 0.12915
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.495
# Mean genetic distance 1.945, standard deviation 0.639
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   28    41      1.0    0.523    10
#     14   13    29      0.9    0.415     1
#     15    9    30      0.9    0.549     0
# Total extinctions: 0
# Generation time: 0.168 sec (0.154 average)
#
#  ****** Running generation 120 ******
#
# Population's average fitness: 0.84853 stdev: 0.10724
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.644
# Mean genetic distance 1.962, standard deviation 0.585
# Population of 101 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   29    37      1.0    0.679    11
#     14   14    36      0.9    0.565     0
#     15   10    28      0.9    0.688     1
# Total extinctions: 0
# Generation time: 0.163 sec (0.153 average)
#
#  ****** Running generation 121 ******
#
# Population's average fitness: 0.86799 stdev: 0.06923
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.336
# Mean genetic distance 1.730, standard deviation 0.582
# Population of 101 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   30    55      1.0    0.325    12
#     14   15    14      1.0    0.334     0
#     15   11    32      0.9    0.348     2
# Total extinctions: 0
# Generation time: 0.134 sec (0.151 average)
#
#  ****** Running generation 122 ******
#
# Population's average fitness: 0.85809 stdev: 0.08859
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.384
# Mean genetic distance 1.852, standard deviation 0.659
# Population of 101 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   31    42      1.0    0.369    13
#     14   16    31      0.9    0.395     1
#     15   12    28      0.9    0.387     3
# Total extinctions: 0
# Generation time: 0.150 sec (0.152 average)
#
#  ****** Running generation 123 ******
#
# Population's average fitness: 0.85413 stdev: 0.10673
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.737
# Mean genetic distance 2.021, standard deviation 0.819
# Population of 100 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   32    37      1.0    0.717    14
#     14   17    21      0.9    0.745     2
#     15   13    41      1.0    0.747     0
#     16    0     1       --       --     0
# Total extinctions: 0
# Generation time: 0.143 sec (0.149 average)
#
#  ****** Running generation 124 ******
#
# Population's average fitness: 0.85147 stdev: 0.09477
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.360
# Mean genetic distance 2.182, standard deviation 1.047
# Population of 99 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   33    42      1.0    0.493    15
#     14   18    18      0.9    0.465     3
#     15   14    36      1.0    0.483     1
#     16    1     3      0.4    0.000     0
# Total extinctions: 0
# Generation time: 0.135 sec (0.150 average)
#
#  ****** Running generation 125 ******
#
# Population's average fitness: 0.84364 stdev: 0.11928
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.429
# Mean genetic distance 2.566, standard deviation 1.273
# Population of 99 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   34    39      1.0    0.520    16
#     14   19    31      0.9    0.518     4
#     15   15    22      0.9    0.525     2
#     16    2     7      0.6    0.151     0
# Total extinctions: 0
# Generation time: 0.186 sec (0.153 average)
#
#  ****** Running generation 126 ******
#
# Population's average fitness: 0.83542 stdev: 0.12897
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.459
# Mean genetic distance 2.518, standard deviation 1.084
# Population of 99 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   35    39      1.0    0.528    17
#     14   20    31      0.9    0.540     5
#     15   16    13      0.9    0.554     3
#     16    3    13      0.7    0.215     0
#     17    0     3       --       --     0
# Total extinctions: 0
# Generation time: 0.143 sec (0.153 average)
#
#  ****** Running generation 127 ******
#
# Population's average fitness: 0.83704 stdev: 0.09982
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.308
# Mean genetic distance 2.714, standard deviation 0.993
# Population of 99 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   36    39      1.0    0.392    18
#     14   21    23      0.9    0.390     6
#     15   17    16      0.9    0.376     4
#     16    4     8      0.8    0.193     0
#     17    1    13      0.8    0.191     0
# Total extinctions: 0
# Generation time: 0.173 sec (0.156 average)
#
#  ****** Running generation 128 ******
#
# Population's average fitness: 0.82761 stdev: 0.12512
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.669
# Mean genetic distance 2.544, standard deviation 0.891
# Population of 99 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   37    32      1.0    0.740    19
#     14   22    19      0.9    0.767     7
#     15   18    20      0.9    0.757     5
#     16    5    14      0.8    0.525     0
#     17    2    14      0.8    0.557     1
# Total extinctions: 0
# Generation time: 0.138 sec (0.153 average)
#
#  ****** Running generation 129 ******
#
# Population's average fitness: 0.83327 stdev: 0.10082
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.498
# Mean genetic distance 2.354, standard deviation 0.787
# Population of 99 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   38    20      1.0    0.544    20
#     14   23    17      0.9    0.552     8
#     15   19    27      0.9    0.563     6
#     16    6    20      0.8    0.416     0
#     17    3    15      0.8    0.416     0
# Total extinctions: 0
# Generation time: 0.178 sec (0.154 average)
#
#  ****** Running generation 130 ******
#
# Population's average fitness: 0.83125 stdev: 0.09476
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.293
# Mean genetic distance 2.251, standard deviation 0.830
# Population of 100 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   39    21      1.0    0.348    21
#     14   24    19      0.9    0.344     9
#     15   20    29      0.9    0.333     7
#     16    7    18      0.9    0.215     0
#     17    4    13      0.8    0.227     1
# Total extinctions: 0
# Generation time: 0.140 sec (0.152 average)
#
#  ****** Running generation 131 ******
#
# Population's average fitness: 0.82533 stdev: 0.12552
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
#
# Species 14 with 19 members is stagnated: removing it
# Average adjusted fitness: 0.528
# Mean genetic distance 2.124, standard deviation 0.761
# Population of 100 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   40    18      1.0    0.587    22
#     15   21    28      1.0    0.616     8
#     16    8    26      0.9    0.448     1
#     17    5    28      0.9    0.461     0
# Total extinctions: 0
# Generation time: 0.132 sec (0.152 average)
#
#  ****** Running generation 132 ******
#
# Population's average fitness: 0.78827 stdev: 0.12781
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.513
# Mean genetic distance 2.026, standard deviation 0.718
# Population of 99 members in 5 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   41    26      1.0    0.568    23
#     15   22    34      0.9    0.557     9
#     16    9    21      0.9    0.454     2
#     17    6    15      1.0    0.471     0
#     18    0     3       --       --     0
# Total extinctions: 0
# Generation time: 0.174 sec (0.154 average)
#
#  ****** Running generation 133 ******
#
# Population's average fitness: 0.83044 stdev: 0.12759
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
#
# Species 15 with 34 members is stagnated: removing it
# Average adjusted fitness: 0.511
# Mean genetic distance 2.347, standard deviation 0.891
# Population of 100 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   42    36      1.0    0.551    24
#     16   10    27      0.9    0.416     0
#     17    7    22      1.0    0.561     1
#     18    1    15      0.9    0.516     0
# Total extinctions: 0
# Generation time: 0.153 sec (0.155 average)
#
#  ****** Running generation 134 ******
#
# Population's average fitness: 0.82547 stdev: 0.12783
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.501
# Mean genetic distance 2.070, standard deviation 0.755
# Population of 100 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   43    24      1.0    0.554    25
#     16   11    19      0.9    0.434     0
#     17    8    37      1.0    0.524     2
#     18    2    20      0.9    0.491     0
# Total extinctions: 0
# Generation time: 0.148 sec (0.157 average)
#
#  ****** Running generation 135 ******
#
# Population's average fitness: 0.86800 stdev: 0.08626
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.538
# Mean genetic distance 1.862, standard deviation 0.680
# Population of 101 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   44    14      1.0    0.544    26
#     16   12    22      0.9    0.547     0
#     17    9    47      1.0    0.519     3
#     18    3    18      0.9    0.541     1
# Total extinctions: 0
# Generation time: 0.173 sec (0.155 average)
#
#  ****** Running generation 136 ******
#
# Population's average fitness: 0.85254 stdev: 0.10358
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.696
# Mean genetic distance 1.894, standard deviation 0.747
# Population of 101 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   45    18      1.0    0.723    27
#     16   13    26      0.9    0.667     1
#     17   10    37      1.0    0.690     4
#     18    4    20      0.9    0.705     2
# Total extinctions: 0
# Generation time: 0.147 sec (0.156 average)
#
#  ****** Running generation 137 ******
#
# Population's average fitness: 0.84964 stdev: 0.12223
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.695
# Mean genetic distance 2.027, standard deviation 0.833
# Population of 101 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   46    20      1.0    0.716    28
#     16   14    16      0.9    0.677     2
#     17   11    44      1.0    0.672     5
#     18    5    21      0.9    0.715     3
# Total extinctions: 0
# Generation time: 0.141 sec (0.152 average)
#
#  ****** Running generation 138 ******
#
# Population's average fitness: 0.84554 stdev: 0.13720
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.742
# Mean genetic distance 1.871, standard deviation 0.771
# Population of 100 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   47    22      1.0    0.787    29
#     16   15    24      1.0    0.716     0
#     17   12    35      1.0    0.726     6
#     18    6    19      0.9    0.737     4
# Total extinctions: 0
# Generation time: 0.133 sec (0.152 average)
#
#  ****** Running generation 139 ******
#
# Population's average fitness: 0.86400 stdev: 0.10667
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.532
# Mean genetic distance 1.875, standard deviation 0.847
# Population of 99 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   48    24      1.0    0.549    30
#     16   16    27      1.0    0.499     1
#     17   13    29      1.0    0.533     7
#     18    7    19      1.0    0.546     0
# Total extinctions: 0
# Generation time: 0.146 sec (0.149 average)
#
#  ****** Running generation 140 ******
#
# Population's average fitness: 0.87084 stdev: 0.07854
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.259
# Mean genetic distance 1.963, standard deviation 0.854
# Population of 99 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   49    23      1.0    0.262    31
#     16   17    32      1.0    0.265     2
#     17   14    23      1.0    0.242     8
#     18    8    21      1.0    0.266     1
# Total extinctions: 0
# Generation time: 0.130 sec (0.148 average)
#
#  ****** Running generation 141 ******
#
# Population's average fitness: 0.86451 stdev: 0.08040
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.292
# Mean genetic distance 2.053, standard deviation 0.936
# Population of 100 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   50    24      1.0    0.288    32
#     16   18    32      1.0    0.279     3
#     17   15    22      1.0    0.313     9
#     18    9    22      1.0    0.290     2
# Total extinctions: 0
# Generation time: 0.174 sec (0.152 average)
#
#  ****** Running generation 142 ******
#
# Population's average fitness: 0.85507 stdev: 0.09803
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
#
# Species 17 with 22 members is stagnated: removing it
# Average adjusted fitness: 0.469
# Mean genetic distance 1.998, standard deviation 0.952
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   51    33      1.0    0.480    33
#     16   19    35      1.0    0.442     4
#     18   10    32      1.0    0.485     3
# Total extinctions: 0
# Generation time: 0.131 sec (0.148 average)
#
#  ****** Running generation 143 ******
#
# Population's average fitness: 0.85080 stdev: 0.12360
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.677
# Mean genetic distance 2.015, standard deviation 0.926
# Population of 99 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   52    32      1.0    0.703    34
#     16   20    40      1.0    0.680     5
#     18   11    26      1.0    0.649     4
#     19    0     1       --       --     0
# Total extinctions: 0
# Generation time: 0.140 sec (0.146 average)
#
#  ****** Running generation 144 ******
#
# Population's average fitness: 0.84902 stdev: 0.12053
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.385
# Mean genetic distance 2.483, standard deviation 1.246
# Population of 99 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   53    34      1.0    0.514    35
#     16   21    35      1.0    0.470     6
#     18   12    28      1.0    0.504     5
#     19    1     2      0.4    0.053     0
# Total extinctions: 0
# Generation time: 0.151 sec (0.147 average)
#
#  ****** Running generation 145 ******
#
# Population's average fitness: 0.85926 stdev: 0.11462
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.440
# Mean genetic distance 2.570, standard deviation 1.238
# Population of 100 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   54    32      1.0    0.550    36
#     16   22    35      1.0    0.540     7
#     18   13    29      1.0    0.556     6
#     19    2     4      0.5    0.113     0
# Total extinctions: 0
# Generation time: 0.234 sec (0.153 average)
#
#  ****** Running generation 146 ******
#
# Population's average fitness: 0.81867 stdev: 0.16191
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.445
# Mean genetic distance 2.883, standard deviation 1.364
# Population of 99 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   55    31      1.0    0.566    37
#     16   23    32      1.0    0.511     8
#     18   14    30      1.0    0.549     7
#     19    3     6      0.5    0.153     0
# Total extinctions: 0
# Generation time: 0.196 sec (0.158 average)
#
#  ****** Running generation 147 ******
#
# Population's average fitness: 0.83663 stdev: 0.14293
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.444
# Mean genetic distance 2.804, standard deviation 1.277
# Population of 101 members in 4 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   56    30      1.0    0.563    38
#     16   24    32      1.0    0.519     9
#     18   15    29      1.0    0.539     8
#     19    4    10      0.7    0.153     0
# Total extinctions: 0
# Generation time: 0.288 sec (0.172 average)
#
#  ****** Running generation 148 ******
#
# Population's average fitness: 0.81201 stdev: 0.16175
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
#
# Species 16 with 32 members is stagnated: removing it
# Average adjusted fitness: 0.471
# Mean genetic distance 2.648, standard deviation 1.166
# Population of 100 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   57    41      1.0    0.584    39
#     18   16    44      1.0    0.619     9
#     19    5    15      0.7    0.212     0
# Total extinctions: 0
# Generation time: 0.292 sec (0.188 average)
#
#  ****** Running generation 149 ******
#
# Population's average fitness: 0.82587 stdev: 0.14587
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
#
# Species 18 with 44 members is stagnated: removing it
# Average adjusted fitness: 0.580
# Mean genetic distance 1.932, standard deviation 0.898
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   58    66      1.0    0.699    40
#     19    6    34      0.8    0.461     0
# Total extinctions: 0
# Generation time: 0.293 sec (0.203 average)
#
#  ****** Running generation 150 ******
#
# Population's average fitness: 0.77373 stdev: 0.15711
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.445
# Mean genetic distance 2.264, standard deviation 0.861
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   59    80      1.0    0.555    41
#     19    7    20      0.8    0.336     0
# Total extinctions: 0
# Generation time: 0.276 sec (0.218 average)
#
#  ****** Running generation 151 ******
#
# Population's average fitness: 0.81627 stdev: 0.12627
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.608
# Mean genetic distance 2.285, standard deviation 1.026
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   60    68      1.0    0.666    42
#     19    8    32      0.8    0.550     1
# Total extinctions: 0
# Generation time: 0.381 sec (0.238 average)
#
#  ****** Running generation 152 ******
#
# Population's average fitness: 0.81000 stdev: 0.14134
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.473
# Mean genetic distance 2.076, standard deviation 0.871
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   61    62      1.0    0.520    43
#     19    9    38      0.9    0.426     0
# Total extinctions: 0
# Generation time: 0.358 sec (0.261 average)
#
#  ****** Running generation 153 ******
#
# Population's average fitness: 0.80587 stdev: 0.13370
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.584
# Mean genetic distance 1.835, standard deviation 0.860
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   62    57      1.0    0.619    44
#     19   10    43      0.9    0.550     0
# Total extinctions: 0
# Generation time: 0.284 sec (0.275 average)
#
#  ****** Running generation 154 ******
#
# Population's average fitness: 0.82907 stdev: 0.09586
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.530
# Mean genetic distance 1.774, standard deviation 0.818
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   63    54      1.0    0.571    45
#     19   11    46      0.9    0.490     0
# Total extinctions: 0
# Generation time: 0.301 sec (0.290 average)
#
#  ****** Running generation 155 ******
#
# Population's average fitness: 0.81467 stdev: 0.13870
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.517
# Mean genetic distance 1.702, standard deviation 0.771
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   64    55      1.0    0.575    46
#     19   12    45      0.9    0.458     0
# Total extinctions: 0
# Generation time: 0.192 sec (0.286 average)
#
#  ****** Running generation 156 ******
#
# Population's average fitness: 0.79893 stdev: 0.16253
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.566
# Mean genetic distance 1.634, standard deviation 0.779
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   65    56      1.0    0.627    47
#     19   13    44      0.9    0.505     1
# Total extinctions: 0
# Generation time: 0.298 sec (0.296 average)
#
#  ****** Running generation 157 ******
#
# Population's average fitness: 0.80453 stdev: 0.16681
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.639
# Mean genetic distance 1.589, standard deviation 0.751
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   66    57      1.0    0.686    48
#     19   14    43      0.9    0.592     2
# Total extinctions: 0
# Generation time: 0.244 sec (0.292 average)
#
#  ****** Running generation 158 ******
#
# Population's average fitness: 0.83787 stdev: 0.12346
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.634
# Mean genetic distance 1.579, standard deviation 0.705
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   67    53      1.0    0.664    49
#     19   15    47      0.9    0.603     3
# Total extinctions: 0
# Generation time: 0.246 sec (0.287 average)
#
#  ****** Running generation 159 ******
#
# Population's average fitness: 0.80027 stdev: 0.16520
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.623
# Mean genetic distance 1.555, standard deviation 0.685
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   68    54      1.0    0.685    50
#     19   16    46      0.9    0.562     4
# Total extinctions: 0
# Generation time: 0.211 sec (0.279 average)
#
#  ****** Running generation 160 ******
#
# Population's average fitness: 0.83933 stdev: 0.11026
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.637
# Mean genetic distance 1.555, standard deviation 0.709
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   69    48      1.0    0.668    51
#     19   17    52      0.9    0.606     5
# Total extinctions: 0
# Generation time: 0.254 sec (0.277 average)
#
#  ****** Running generation 161 ******
#
# Population's average fitness: 0.83120 stdev: 0.12831
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.513
# Mean genetic distance 1.604, standard deviation 0.660
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   70    53      1.0    0.559    52
#     19   18    47      0.9    0.467     6
# Total extinctions: 0
# Generation time: 0.260 sec (0.265 average)
#
#  ****** Running generation 162 ******
#
# Population's average fitness: 0.80347 stdev: 0.15666
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.534
# Mean genetic distance 1.612, standard deviation 0.691
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   71    57      1.0    0.576    53
#     19   19    43      0.9    0.492     7
# Total extinctions: 0
# Generation time: 0.148 sec (0.244 average)
#
#  ****** Running generation 163 ******
#
# Population's average fitness: 0.83627 stdev: 0.10835
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.514
# Mean genetic distance 1.623, standard deviation 0.709
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   72    60      1.0    0.529    54
#     19   20    40      0.9    0.499     8
# Total extinctions: 0
# Generation time: 0.140 sec (0.229 average)
#
#  ****** Running generation 164 ******
#
# Population's average fitness: 0.82520 stdev: 0.13418
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.507
# Mean genetic distance 1.666, standard deviation 0.756
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   73    64      1.0    0.566    55
#     19   21    36      0.9    0.447     9
# Total extinctions: 0
# Generation time: 0.160 sec (0.215 average)
#
#  ****** Running generation 165 ******
#
# Population's average fitness: 0.82480 stdev: 0.14007
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
#
# Species 19 with 36 members is stagnated: removing it
# Average adjusted fitness: 0.494
# Mean genetic distance 1.175, standard deviation 0.477
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   74   100      1.0    0.494    56
# Total extinctions: 0
# Generation time: 0.147 sec (0.211 average)
#
#  ****** Running generation 166 ******
#
# Population's average fitness: 0.85733 stdev: 0.09711
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.484
# Mean genetic distance 1.140, standard deviation 0.461
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   75   100      1.0    0.484    57
# Total extinctions: 0
# Generation time: 0.176 sec (0.199 average)
#
#  ****** Running generation 167 ******
#
# Population's average fitness: 0.84293 stdev: 0.11076
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.523
# Mean genetic distance 1.107, standard deviation 0.458
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   76   100      1.0    0.523    58
# Total extinctions: 0
# Generation time: 0.144 sec (0.189 average)
#
#  ****** Running generation 168 ******
#
# Population's average fitness: 0.86013 stdev: 0.09246
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.513
# Mean genetic distance 1.164, standard deviation 0.460
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   77   100      1.0    0.513    59
# Total extinctions: 0
# Generation time: 0.131 sec (0.177 average)
#
#  ****** Running generation 169 ******
#
# Population's average fitness: 0.84293 stdev: 0.11901
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.563
# Mean genetic distance 1.142, standard deviation 0.466
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   78   100      1.0    0.563    60
# Total extinctions: 0
# Generation time: 0.200 sec (0.176 average)
#
#  ****** Running generation 170 ******
#
# Population's average fitness: 0.85813 stdev: 0.09412
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.485
# Mean genetic distance 1.085, standard deviation 0.465
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   79   100      1.0    0.485    61
# Total extinctions: 0
# Generation time: 0.210 sec (0.172 average)
#
#  ****** Running generation 171 ******
#
# Population's average fitness: 0.86413 stdev: 0.09761
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.731
# Mean genetic distance 1.086, standard deviation 0.459
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   80   100      1.0    0.731    62
# Total extinctions: 0
# Generation time: 0.102 sec (0.156 average)
#
#  ****** Running generation 172 ******
#
# Population's average fitness: 0.84413 stdev: 0.12060
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.684
# Mean genetic distance 1.174, standard deviation 0.418
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   81   100      1.0    0.684    63
# Total extinctions: 0
# Generation time: 0.070 sec (0.148 average)
#
#  ****** Running generation 173 ******
#
# Population's average fitness: 0.85440 stdev: 0.09458
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.414
# Mean genetic distance 1.299, standard deviation 0.535
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   82   100      1.0    0.414    64
# Total extinctions: 0
# Generation time: 0.099 sec (0.144 average)
#
#  ****** Running generation 174 ******
#
# Population's average fitness: 0.83827 stdev: 0.12135
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.532
# Mean genetic distance 1.255, standard deviation 0.467
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   83   100      1.0    0.532    65
# Total extinctions: 0
# Generation time: 0.075 sec (0.135 average)
#
#  ****** Running generation 175 ******
#
# Population's average fitness: 0.85067 stdev: 0.11779
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.517
# Mean genetic distance 1.201, standard deviation 0.466
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   84   100      1.0    0.517    66
# Total extinctions: 0
# Generation time: 0.091 sec (0.130 average)
#
#  ****** Running generation 176 ******
#
# Population's average fitness: 0.85920 stdev: 0.11146
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.539
# Mean genetic distance 1.286, standard deviation 0.526
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   85   100      1.0    0.539    67
# Total extinctions: 0
# Generation time: 0.105 sec (0.123 average)
#
#  ****** Running generation 177 ******
#
# Population's average fitness: 0.83947 stdev: 0.11098
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.506
# Mean genetic distance 1.177, standard deviation 0.420
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   86   100      1.0    0.506    68
# Total extinctions: 0
# Generation time: 0.082 sec (0.116 average)
#
#  ****** Running generation 178 ******
#
# Population's average fitness: 0.84507 stdev: 0.12290
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.618
# Mean genetic distance 1.911, standard deviation 1.073
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   87    99      1.0    0.618    69
#     20    0     1       --       --     0
# Total extinctions: 0
# Generation time: 0.074 sec (0.111 average)
#
#  ****** Running generation 179 ******
#
# Population's average fitness: 0.85253 stdev: 0.08399
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.134
# Mean genetic distance 2.109, standard deviation 1.129
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   88    90      1.0    0.228    70
#     20    1    10      0.7    0.040     0
# Total extinctions: 0
# Generation time: 0.120 sec (0.103 average)
#
#  ****** Running generation 180 ******
#
# Population's average fitness: 0.84187 stdev: 0.10774
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.270
# Mean genetic distance 2.353, standard deviation 1.040
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   89    83      1.0    0.385    71
#     20    2    17      0.9    0.156     0
# Total extinctions: 0
# Generation time: 0.091 sec (0.091 average)
#
#  ****** Running generation 181 ******
#
# Population's average fitness: 0.80693 stdev: 0.15781
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.558
# Mean genetic distance 2.219, standard deviation 0.882
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   90    66      1.0    0.673    72
#     20    3    34      0.9    0.443     0
# Total extinctions: 0
# Generation time: 0.089 sec (0.090 average)
#
#  ****** Running generation 182 ******
#
# Population's average fitness: 0.81987 stdev: 0.11537
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.460
# Mean genetic distance 2.032, standard deviation 0.765
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   91    60      1.0    0.501    73
#     20    4    40      0.9    0.420     0
# Total extinctions: 0
# Generation time: 0.097 sec (0.092 average)
#
#  ****** Running generation 183 ******
#
# Population's average fitness: 0.83053 stdev: 0.10727
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.447
# Mean genetic distance 1.701, standard deviation 0.669
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   92    51      1.0    0.500    74
#     20    5    49      0.9    0.393     1
# Total extinctions: 0
# Generation time: 0.075 sec (0.090 average)
#
#  ****** Running generation 184 ******
#
# Population's average fitness: 0.83733 stdev: 0.11924
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.637
# Mean genetic distance 1.527, standard deviation 0.591
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   93    47      1.0    0.660    75
#     20    6    53      0.9    0.614     0
# Total extinctions: 0
# Generation time: 0.090 sec (0.091 average)
#
#  ****** Running generation 185 ******
#
# Population's average fitness: 0.82360 stdev: 0.12113
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.505
# Mean genetic distance 1.464, standard deviation 0.551
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   94    49      1.0    0.520    76
#     20    7    51      0.9    0.489     1
# Total extinctions: 0
# Generation time: 0.111 sec (0.093 average)
#
#  ****** Running generation 186 ******
#
# Population's average fitness: 0.85347 stdev: 0.08765
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.521
# Mean genetic distance 1.443, standard deviation 0.523
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   95    45      1.0    0.546    77
#     20    8    55      0.9    0.495     2
# Total extinctions: 0
# Generation time: 0.079 sec (0.091 average)
#
#  ****** Running generation 187 ******
#
# Population's average fitness: 0.85213 stdev: 0.09933
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.533
# Mean genetic distance 1.344, standard deviation 0.483
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   96    48      1.0    0.546    78
#     20    9    52      0.9    0.521     3
# Total extinctions: 0
# Generation time: 0.077 sec (0.090 average)
#
#  ****** Running generation 188 ******
#
# Population's average fitness: 0.85040 stdev: 0.10389
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.558
# Mean genetic distance 1.492, standard deviation 0.573
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   97    50      1.0    0.569    79
#     20   10    50      0.9    0.546     4
# Total extinctions: 0
# Generation time: 0.116 sec (0.094 average)
#
#  ****** Running generation 189 ******
#
# Population's average fitness: 0.84773 stdev: 0.10015
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.408
# Mean genetic distance 1.461, standard deviation 0.588
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   98    49      1.0    0.437    80
#     20   11    51      0.9    0.378     5
# Total extinctions: 0
# Generation time: 0.124 sec (0.095 average)
#
#  ****** Running generation 190 ******
#
# Population's average fitness: 0.83693 stdev: 0.13758
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.557
# Mean genetic distance 1.500, standard deviation 0.618
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13   99    48      1.0    0.568    81
#     20   12    52      0.9    0.547     6
# Total extinctions: 0
# Generation time: 0.092 sec (0.095 average)
#
#  ****** Running generation 191 ******
#
# Population's average fitness: 0.84400 stdev: 0.11159
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.685
# Mean genetic distance 1.477, standard deviation 0.593
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13  100    50      1.0    0.701    82
#     20   13    50      0.9    0.668     7
# Total extinctions: 0
# Generation time: 0.126 sec (0.099 average)
#
#  ****** Running generation 192 ******
#
# Population's average fitness: 0.84013 stdev: 0.11049
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.467
# Mean genetic distance 1.485, standard deviation 0.624
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13  101    42      1.0    0.490    83
#     20   14    58      0.9    0.444     8
# Total extinctions: 0
# Generation time: 0.117 sec (0.101 average)
#
#  ****** Running generation 193 ******
#
# Population's average fitness: 0.82093 stdev: 0.15995
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.626
# Mean genetic distance 1.464, standard deviation 0.635
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13  102    49      1.0    0.655    84
#     20   15    51      0.9    0.597     9
# Total extinctions: 0
# Generation time: 0.070 sec (0.100 average)
#
#  ****** Running generation 194 ******
#
# Population's average fitness: 0.85893 stdev: 0.12412
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
#
# Species 20 with 51 members is stagnated: removing it
# Average adjusted fitness: 0.691
# Mean genetic distance 1.088, standard deviation 0.486
# Population of 100 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13  103   100      1.0    0.691    85
# Total extinctions: 0
# Generation time: 0.077 sec (0.099 average)
#
#  ****** Running generation 195 ******
#
# Population's average fitness: 0.86413 stdev: 0.08558
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.411
# Mean genetic distance 1.965, standard deviation 1.184
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13  104    98      1.0    0.411    86
#     21    0     2       --       --     0
# Total extinctions: 0
# Generation time: 0.082 sec (0.096 average)
#
#  ****** Running generation 196 ******
#
# Population's average fitness: 0.86227 stdev: 0.08690
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.359
# Mean genetic distance 2.235, standard deviation 1.125
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13  105    79      1.0    0.411    87
#     21    1    21      0.8    0.307     0
# Total extinctions: 0
# Generation time: 0.105 sec (0.098 average)
#
#  ****** Running generation 197 ******
#
# Population's average fitness: 0.83827 stdev: 0.09365
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.269
# Mean genetic distance 2.503, standard deviation 1.162
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13  106    69      1.0    0.331    88
#     21    2    31      0.8    0.208     0
# Total extinctions: 0
# Generation time: 0.103 sec (0.101 average)
#
#  ****** Running generation 198 ******
#
# Population's average fitness: 0.83947 stdev: 0.09820
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.412
# Mean genetic distance 2.355, standard deviation 1.170
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13  107    60      1.0    0.449    89
#     21    3    40      0.8    0.375     0
# Total extinctions: 0
# Generation time: 0.072 sec (0.097 average)
#
#  ****** Running generation 199 ******
#
# Population's average fitness: 0.80973 stdev: 0.11893
# Best fitness: 0.97333 - size: (2, 4) - species 13 - id 10426
# Average adjusted fitness: 0.482
# Mean genetic distance 2.472, standard deviation 1.169
# Population of 100 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#     13  108    55      1.0    0.522    90
#     21    4    45      0.9    0.441     0
# Total extinctions: 0
# Generation time: 0.071 sec (0.091 average)
# 🏁 Final winner: 2 nodes, 4 connections
# ✅ Final model structure:
# Linear(in_features=4, out_features=2, bias=True)

# %%
print("✅ Saving model structure:")
for i, layer in enumerate(model.layers):
    print(f"Layer {i}: {layer}")
# Out:
# ✅ Saving model structure:
# Layer 0: Linear(in_features=4, out_features=4, bias=True)
# Layer 1: Linear(in_features=4, out_features=2, bias=True)

# %%
import pickle

with open("model_neat.pth", "wb") as f:
    pickle.dump(winner, f)

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (0.20.3)

# %%
# !cp ./visualize.py /usr/local/lib/python3.11/dist-packages/neat/visualize.py

# %%
# !ls -lta /usr/local/lib/python3.11/dist-packages/neat
# !chmod 644 /usr/local/lib/python3.11/dist-packages/neat/visualize.py
# Out:
# total 192
# -rw-r--r-- 1 root root  5493 Apr 18 13:47 visualize.py
# drwxr-xr-x 2 root root  4096 Apr 18 13:38 __pycache__
# drwxr-xr-x 6 root root  4096 Apr 18 13:29 .
# drwxr-xr-x 3 root root  4096 Apr 18 13:20 nn
# drwxr-xr-x 3 root root  4096 Apr 18 13:20 iznn
# drwxr-xr-x 3 root root  4096 Apr 18 13:20 ctrnn
# drwxr-xr-x 1 root root  4096 Apr 18 13:20 ..
# -rw-r--r-- 1 root root  3053 Apr 18 13:20 activations.py
# -rw-r--r-- 1 root root 24215 Apr 18 13:20 genome.py
# -rw-r--r-- 1 root root  3297 Apr 18 13:20 checkpoint.py
# -rw-r--r-- 1 root root  4436 Apr 18 13:20 genes.py
# -rw-r--r-- 1 root root  2851 Apr 18 13:20 graphs.py
# -rw-r--r-- 1 root root  5367 Apr 18 13:20 species.py
# -rw-r--r-- 1 root root 22826 Apr 18 13:20 distributed.py
# -rw-r--r-- 1 root root  1195 Apr 18 13:20 math_util.py
# -rw-r--r-- 1 root root  1046 Apr 18 13:20 parallel.py
# -rw-r--r-- 1 root root  5834 Apr 18 13:20 population.py
# -rw-r--r-- 1 root root   685 Apr 18 13:20 six_util.py
# -rw-r--r-- 1 root root  2251 Apr 18 13:20 aggregations.py
# -rw-r--r-- 1 root root  8988 Apr 18 13:20 config.py
# -rw-r--r-- 1 root root  3382 Apr 18 13:20 stagnation.py
# -rw-r--r-- 1 root root  6011 Apr 18 13:20 attributes.py
# -rw-r--r-- 1 root root   742 Apr 18 13:20 __init__.py
# -rw-r--r-- 1 root root  5924 Apr 18 13:20 reporting.py
# -rw-r--r-- 1 root root  6594 Apr 18 13:20 statistics.py
# -rw-r--r-- 1 root root  8065 Apr 18 13:20 reproduction.py
# -rw-r--r-- 1 root root  2940 Apr 18 13:20 threaded.py

# %%
# !ls -lta /usr/local/lib/python3.11/dist-packages/neat
# !rm /usr/local/lib/python3.11/dist-packages/neat/__pycache__/*
# Out:
# total 192
# -rw-r--r-- 1 root root  5493 Apr 18 13:47 visualize.py
# drwxr-xr-x 2 root root  4096 Apr 18 13:38 __pycache__
# drwxr-xr-x 6 root root  4096 Apr 18 13:29 .
# drwxr-xr-x 3 root root  4096 Apr 18 13:20 nn
# drwxr-xr-x 3 root root  4096 Apr 18 13:20 iznn
# drwxr-xr-x 3 root root  4096 Apr 18 13:20 ctrnn
# drwxr-xr-x 1 root root  4096 Apr 18 13:20 ..
# -rw-r--r-- 1 root root  3053 Apr 18 13:20 activations.py
# -rw-r--r-- 1 root root 24215 Apr 18 13:20 genome.py
# -rw-r--r-- 1 root root  3297 Apr 18 13:20 checkpoint.py
# -rw-r--r-- 1 root root  4436 Apr 18 13:20 genes.py
# -rw-r--r-- 1 root root  2851 Apr 18 13:20 graphs.py
# -rw-r--r-- 1 root root  5367 Apr 18 13:20 species.py
# -rw-r--r-- 1 root root 22826 Apr 18 13:20 distributed.py
# -rw-r--r-- 1 root root  1195 Apr 18 13:20 math_util.py
# -rw-r--r-- 1 root root  1046 Apr 18 13:20 parallel.py
# -rw-r--r-- 1 root root  5834 Apr 18 13:20 population.py
# -rw-r--r-- 1 root root   685 Apr 18 13:20 six_util.py
# -rw-r--r-- 1 root root  2251 Apr 18 13:20 aggregations.py
# -rw-r--r-- 1 root root  8988 Apr 18 13:20 config.py
# -rw-r--r-- 1 root root  3382 Apr 18 13:20 stagnation.py
# -rw-r--r-- 1 root root  6011 Apr 18 13:20 attributes.py
# -rw-r--r-- 1 root root   742 Apr 18 13:20 __init__.py
# -rw-r--r-- 1 root root  5924 Apr 18 13:20 reporting.py
# -rw-r--r-- 1 root root  6594 Apr 18 13:20 statistics.py
# -rw-r--r-- 1 root root  8065 Apr 18 13:20 reproduction.py
# -rw-r--r-- 1 root root  2940 Apr 18 13:20 threaded.py
# rm: cannot remove '/usr/local/lib/python3.11/dist-packages/neat/__pycache__/*': No such file or directory

# %%
# !ls -lta /usr/local/lib/python3.11/dist-packages/neat/__pycache__
# Out:
# total 8
# drwxr-xr-x 2 root root 4096 Apr 18 13:38 .
# drwxr-xr-x 6 root root 4096 Apr 18 13:29 ..

# %%
import neat
import os
import matplotlib.pyplot as plt
import pickle
import neat.visualize as visualize

# Load config
config_path = "neat_cfg_vis.txt"
config = neat.Config(
    neat.DefaultGenome,
    neat.DefaultReproduction,
    neat.DefaultSpeciesSet,
    neat.DefaultStagnation,
    config_path)

# Load the winner genome
with open("winner_genome.pkl", "rb") as f:
    winner = pickle.load(f)

# Define node names (customize for your input/output features)
node_names = {
    -1: "avg_f0",
    -2: "jitter_s",
    -3: "shimmer",
    -4: "mean_hnr",
    0: "Non-Autistic",
    1: "Autistic",
}

# Visualize the winner network directly
neat.visualize.draw_net(config, winner, view=True, node_names=node_names, filename="./winner_topology.png", show_disabled=True)


plt.show()

# %%
# !ls -lta
# !pwd
# Out:
# total 95274
# -rw------- 1 root root      452 Apr 18 13:47  winner_topology.png
# -rw------- 1 root root     2649 Apr 18 13:47  winner_topology.png.svg
# -rw------- 1 root root   741760 Apr 18 13:47  NEAT_Forward_Backpropagation_Tuning.ipynb
# -rw------- 1 root root      359 Apr 18 13:47  model_neat.pth
# -rw------- 1 root root      359 Apr 18 13:47  winner_genome.pkl
# -rw------- 1 root root     2280 Apr 18 13:44  evolved_neat_model.pt
# -rw------- 1 root root     3605 Apr 18 13:36  backprop_log.json
# -rw------- 1 root root 96437100 Apr 18 13:36  complexity_log.json
# -rw------- 1 root root     2706 Apr 18 13:36  fitness_log.json
# -rw------- 1 root root    15712 Apr 18 13:35  network.png
# -rw------- 1 root root     1771 Apr 18 13:35  neat_fitness_log.json
# -rw------- 1 root root      471 Apr 18 13:34  evolved_neat_model.pkl
# -rw------- 1 root root     1861 Apr 13 19:57  neat_cfg_vis.txt
# -rw------- 1 root root      508 Apr  7 19:25 'Copy of model_neat.pth'
# -rw------- 1 root root     2630 Apr  7 19:04 'Copy of model_neat (1).pth'
# -rw------- 1 root root      583 Apr  2 17:29  neat_model.onnx
# -rw------- 1 root root      468 Apr  1 21:26 'Copy of winner_genome.pkl'
# -rw------- 1 root root     1950 Apr  1 21:16  neat_config.txt
# -rw------- 1 root root   303243 Apr  1 05:28  NN_NEAT.ipynb
# -rw------- 1 root root    21709 Mar 27 22:50  voice_data.csv
# drwx------ 2 root root     4096 Mar 26 16:28  StreamlitApp
# drwx------ 2 root root     4096 Mar 23 22:12  FlaskApp
# -rw------- 1 root root     5493 Mar 22 13:01  visualize.py
# /content/drive/MyDrive/Colab Notebooks/cours_python/FSCI2610/projet/Finale/NEAT

# %%
import pickle
import neat
import matplotlib.pyplot as plt
from collections import defaultdict

# Load config
config_path = "neat_cfg_vis.txt"
config = neat.Config(
    neat.DefaultGenome,
    neat.DefaultReproduction,
    neat.DefaultSpeciesSet,
    neat.DefaultStagnation,
    config_path
)

# Load evolved winner genome
#evolved_neat_model.pkl
#winner_genome.pkl
with open("winner_genome.pkl", "rb") as f:
    winner = pickle.load(f)

# Compute input sensitivity (sum of absolute weights)
input_sensitivity = defaultdict(float)
for (input_node, output_node), conn in winner.connections.items():
    if conn.enabled and input_node < 0:  # NEAT uses negative IDs for input nodes
        input_sensitivity[input_node] += abs(conn.weight)

# Input label mapping
input_labels = {
    -1: "avg_f0",
    -2: "jitter_s",
    -3: "shimmer",
    -4: "mean_hnr"
}

# Prepare data
labels = [input_labels[i] for i in sorted(input_sensitivity.keys())]
sensitivities = [input_sensitivity[i] for i in sorted(input_sensitivity.keys())]

# Plot bar chart
plt.figure(figsize=(8, 5))
plt.bar(labels, sensitivities, color='lightcoral')
plt.title("Input Sensitivity (Sum of Absolute Connection Weights)")
plt.ylabel("Total Influence")
plt.xlabel("Input Features")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Upload the complexity log from NEAT run

# Parse complexity_log.json
generation_data = []
with open("complexity_log.json", "r") as f:
    for line in f:
        try:
            gen = json.loads(line)
            generation_data.append(gen)
        except json.JSONDecodeError:
            continue

# Aggregate average complexity and fitness per generation
avg_connections = []
avg_nodes = []
avg_raw_fitness = []
avg_smoothed_fitness = []

for gen in generation_data:
    if not gen: continue
    avg_connections.append(sum(g['connections'] for g in gen) / len(gen))
    avg_nodes.append(sum(g['nodes'] for g in gen) / len(gen))
    avg_raw_fitness.append(sum(g['raw_fitness'] for g in gen) / len(gen))
    avg_smoothed_fitness.append(sum(g['smoothed_fitness'] for g in gen) / len(gen))

generations = list(range(1, len(avg_connections) + 1))

# Plot: Accuracy vs. Connections
plt.figure(figsize=(10, 5))
plt.plot(generations, avg_raw_fitness, label='Raw Fitness', color='blue')
plt.plot(generations, avg_smoothed_fitness, label='Smoothed Fitness', color='green')
plt.xlabel("Generation")
plt.ylabel("Fitness (Accuracy)")
plt.title("Fitness Over Generations")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Plot: Connections vs. Fitness
plt.figure(figsize=(10, 5))
plt.plot(avg_connections, avg_raw_fitness, 'o-', label='Raw Fitness')
plt.plot(avg_connections, avg_smoothed_fitness, 'x-', label='Smoothed Fitness')
plt.xlabel("Avg. Number of Connections")
plt.ylabel("Fitness (Accuracy)")
plt.title("Fitness vs. Network Complexity (Connections)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import torch

print(model.state_dict())

# Save model weights to disk
torch.save(model.state_dict(), "evolved_neat_model.pt")
print("Model saved to evolved_neat_model.pt")
# Out:
# OrderedDict([('layers.0.weight', tensor([[-0.2439,  0.1891, -0.0047,  0.2490],
#         [-0.3728, -0.3312,  0.1375, -0.4355]])), ('layers.0.bias', tensor([-0.0989, -0.2019]))])
# Model saved to evolved_neat_model.pt

# %%
# Reconstruct model using same config and winner genome
neat_net = neat.nn.FeedForwardNetwork.create(winner, config)
model = EvolvedNN(neat_net, winner)

# Load saved weights
model.load_state_dict(torch.load("evolved_neat_model.pt"))
model.eval()  # Set to evaluation mode
# Out:
# EvolvedNN(
#   (layers): ModuleList(
#     (0): Linear(in_features=4, out_features=4, bias=True)
#     (1): Linear(in_features=4, out_features=2, bias=True)
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# Example input (batch of 4 feature values)

test_data_positif = [[-5.46995793e-01,-1.03386570e-02,3.66745546e-01,4.09173981e-01]]  #positif
test_data_negatif = [[1.21077695e+00,5.76813938e-01,5.47940620e-01,-1.56576047e+00]]  #négatif
sample1 = torch.tensor(test_data_positif, dtype=torch.float32)
sample2 = torch.tensor(test_data_negatif, dtype=torch.float32)

for sample in [sample1, sample2]:
  # Run prediction
  with torch.no_grad():
    output = model(sample)
    pred_class = torch.argmax(output, dim=1).item()

  print(f"\nPredicted class for sample {sample}:", pred_class)
# Out:
# Predicted class for sample tensor([[-0.5470, -0.0103,  0.3667,  0.4092]]): 0
#
# Predicted class for sample tensor([[ 1.2108,  0.5768,  0.5479, -1.5658]]): 1

# %%
import torch

x = None

# Load the pre-trained model's state dictionary
checkpoint = torch.load('evolved_neat_model.pt')
print(checkpoint)

neat_net = neat.nn.FeedForwardNetwork.create(winner, config)
model = EvolvedNN(neat_net, winner)

# Load the state dictionary into your model, ignoring mismatched layers
try:
    #model.load_state_dict(checkpoint['state_dict'], strict=False)
    model.load_state_dict(checkpoint, strict = False)#strict=True)
except RuntimeError as e:
    print(f"RuntimeError: {e}")
    # Handle the mismatch (e.g., selectively load layers)

model.eval()
# Out:
# OrderedDict([('layers.0.weight', tensor([[ 0.0827,  0.3852, -0.3317, -0.3094],
#         [-0.1171, -0.0059,  0.2161,  0.1051],
#         [ 0.5057,  0.0508, -0.4725,  0.4704],
#         [-0.1941, -0.3395,  0.2148,  0.8057]])), ('layers.0.bias', tensor([ 0.1065,  0.3397, -0.1510,  0.1165])), ('layers.1.weight', tensor([[ 0.0554, -0.1437, -0.3226, -0.3751],
#         [ 0.1279, -0.8385,  0.4631,  0.0496]])), ('layers.1.bias', tensor([-0.2258, -0.5744]))])
# EvolvedNN(
#   (layers): ModuleList(
#     (0): Linear(in_features=4, out_features=4, bias=True)
#     (1): Linear(in_features=4, out_features=2, bias=True)
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
# !pip install onnx
# Out:
# Collecting onnx
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx) (5.29.4)
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 83.0 MB/s eta 0:00:00
# Installing collected packages: onnx
# Successfully installed onnx-1.17.0

# %%
torch.onnx.export(model, sample, "./neat_model.onnx", input_names=["input"], output_names=["output"])

# %% [markdown]
# **Attention**: Le reste du code était un essai de deployer Streamlit à l'interieur de Google Colab. il m'est devenu apparent après essaies et recherche que celà n'est pas possible. Il s'agit de la limite de l'environment Google Colab atteinte, j'ai donc brancher vers strictement Python (eg .py) sur mon iMac au lieu de mon ipad et j'ai deployé l'pplication Streamlit et Flask localement.
#
#
# **Important**: Les applications Streamlit et Flask sont inclus dans leur répertoire respectif.  Voir les répertoires StreamlitApp et FlaskApp.
#
#
# **Donc, le reste du code est sans objet puisque l'environnement google colab ne permet pas le deploiement locale d'application web.**

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.44.0-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.23.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.44.0-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 44.6 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 50.2 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.44.0 watchdog-6.0.0

# %%
import streamlit as st
import torch
import numpy as np
import matplotlib.pyplot as plt

# Load trained model
neat_net = neat.nn.FeedForwardNetwork.create(winner, config)
model = EvolvedNN(neat_net, winner)
model.load_state_dict(torch.load("evolved_neat_model.pth"))
model.eval()

st.title("Autism Voice Classifier Dashboard")

# Input
st.header("Input Voice Features")
feat1 = st.slider("avg_F1", -1.0, 1.0, 0.0)
feat2 = st.slider("jitter_s", -1.0, 1.0, 0.0)
feat3 = st.slider("shimmer", -1.0, 1.0, 0.0)
feat4 = st.slider("mean_hnr", -1.0, 1.0, 0.0)

if st.button("Predict"):
    input_tensor = torch.tensor([[avg_F1, jitter_s, shimmer, mean_hnr]], dtype=torch.float32)
    with torch.no_grad():
        output = model(input_tensor)
        prediction = torch.argmax(output, dim=1).item()
        label = "Autistic" if prediction == 1 else "Non-Autistic"
        st.success(f"Predicted Class: **{label}**")

# Feature Importance
st.header("Feature Importance (Input Sensitivity)")

from collections import defaultdict

input_sensitivity = defaultdict(float)
for (in_node, out_node), conn in winner.connections.items():
    if conn.enabled and in_node < 0:
        input_sensitivity[in_node] += abs(conn.weight)

input_labels = {-1: "avg_F1", -2: "jitter_s", -3: "shimmer", -4: "mean_hnr"}
labels = [input_labels[i] for i in sorted(input_sensitivity.keys())]
sensitivities = [input_sensitivity[i] for i in sorted(input_sensitivity.keys())]

fig, ax = plt.subplots()
ax.bar(labels, sensitivities, color='lightblue')
ax.set_title("Input Sensitivity")
ax.set_ylabel("Total Absolute Weight")
st.pyplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-55c1ea3bf350> in <cell line: 0>()
# ----> 1 import streamlit as st
#       2 import torch
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# evolved_model.py or app.py

import neat
import pickle
import torch.nn as nn
import torch

# Load NEAT config
config = neat.Config(
    neat.DefaultGenome,
    neat.DefaultReproduction,
    neat.DefaultSpeciesSet,
    neat.DefaultStagnation,
    "neat_cfg_vis.txt"
)

# Load winner genome
with open("winner_genome.pkl", "rb") as f:
    winner = pickle.load(f)

# Define the evolved PyTorch model
class EvolvedNN(nn.Module):
    def __init__(self, neat_net, genome):
        super().__init__()
        self.layers = nn.ModuleList()
        self.node_map = {}
        layer_index = 0
        neuron_index = 0

        for node_id in neat_net.input_nodes:
            self.node_map[node_id] = (layer_index, neuron_index)
            neuron_index += 1

        hidden_nodes = [n for n in genome.nodes if n not in neat_net.input_nodes and n not in neat_net.output_nodes]
        num_hidden = len(hidden_nodes)

        if num_hidden > 0:
            layer_index += 1
            neuron_index = 0
            self.layers.append(nn.Linear(len(neat_net.input_nodes), num_hidden))
            for node_id in hidden_nodes:
                self.node_map[node_id] = (layer_index, neuron_index)
                neuron_index += 1

        layer_index += 1
        neuron_index = 0
        input_size = num_hidden if num_hidden > 0 else len(neat_net.input_nodes)
        self.layers.append(nn.Linear(input_size, len(neat_net.output_nodes)))
        for node_id in neat_net.output_nodes:
            self.node_map[node_id] = (layer_index, neuron_index)
            neuron_index += 1

        self.load_neat_weights(genome)

    def forward(self, x):
        for i, layer in enumerate(self.layers):
            x = layer(x)
            if i < len(self.layers) - 1 and i > 0:
                x = torch.relu(x)
        return x

    def load_neat_weights(self, genome):
        for conn in genome.connections.values():
            if conn.enabled:
                in_node, out_node = conn.key
                weight = conn.weight
                in_layer, in_neuron = self.node_map.get(in_node, (None, None))
                out_layer, out_neuron = self.node_map.get(out_node, (None, None))
                if in_layer is not None and out_layer is not None and out_layer < len(self.layers):
                    try:
                        self.layers[out_layer].weight.data[out_neuron, in_neuron] = weight
                        self.layers[out_layer].bias.data[out_neuron] = genome.nodes[out_node].bias
                    except IndexError:
                        pass

# %%
# !streamlit run ./StreamlitApp/app.py
#This should be executed outside google colab.
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: ./StreamlitApp/app.py

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/cours_python/FSCI2610/projet/Finale/NEAT/StreamlitApp

# %%
  # !pwd
# !ls -lta
#!cd StreamlitApp/
#!ls -lta
# Out:
# /content/drive/MyDrive/Colab Notebooks/cours_python/FSCI2610/projet/Finale/NEAT/StreamlitApp
# total 0
